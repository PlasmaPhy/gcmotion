# %%
import gcmotion as gcm
import numpy as np
import guide_parameters as parameters

# %%
collection = gcm.Collection(parameters)
collection.run_all(orbit=True, terminal=8)
# Out:
# Checking Data...
# Data is OK. Number of particles = 15
# 100%|██████████| 15/15 [00:00<00:00, 20.11it/s]
# Total calculation time: 0.7435s.
# Fastest particle: 0.02772s.
# Slowest particle: 0.07527s.
# Average time: (0.04957 ± 0.01623)s.
# 5 particles reached the end of the integration interval.
# 10 particles were terminated early.

# %%
gcm.collection_energy_contour(
    collection,
    psi_lim="auto",
    plot_drift=True,
    contour_Phi=True,
    units="eV",
    levels=30,
    plot_initial=True,
    different_colors=False,
    adjust_cbar=True,
)
# Out:
# [array([4425.2948772 , 3763.2941857 , 3183.02607862, 2676.05354316,
#        2234.88603618, 1852.86059468, 1524.03928216, 1243.12060119,
#        1005.3628483 ,  806.5176863 ,  642.77246662,  510.70005396,
#         407.21509271,  329.53581286,  275.15060814])]
