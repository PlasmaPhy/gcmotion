# %%
import gcmotion as gcm
import radial_paper_parameters as parameters

# %%
collection = gcm.Collection(parameters)
collection.run_all(orbit=True, terminal=10)
# Out:
# Checking Data...
# Data is OK. Number of particles = 8
# 100%|██████████| 8/8 [00:03<00:00,  2.29it/s]
# Total calculation time: 3.488s.
# Fastest particle: 0.2325s.
# Slowest particle: 0.6269s.
# Average time: (0.436 ± 0.1395)s.
# 4 particles reached the end of the integration interval.
# 4 particles were terminated early.

# %%
cwp = collection.particles[0]
print(cwp.w0)
print(cwp.NU_to_eV*1000)
# Out:
# 95788331.77075665
# 260783733245.88495

# %%
gcm.tokamak_profile(collection.particles[0], zoom = [0.8, 1.1])

# %%
print(collection.particles[3].E_eV/1000)
# Out:
# 1.7167916910721124

# %%
gcm.collection_energy_contour(
    collection,
    psi_lim="auto",
    plot_drift=True,
    contour_Phi=True,
    units="keV",
    levels=30,
    different_colors=False,
    plot_initial=True
)
# Out:
# [array([0.87180523, 0.68517226, 0.71389863, 1.71679169, 1.96418417,
#        1.93080089, 1.4724043 , 2.39485814])]

# %%
gcm.collection_poloidal_cut(collection)
